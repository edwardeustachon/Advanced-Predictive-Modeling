# %% [markdown]
# # <p style="text-align: center;">MIS382: Advanced Predictive Modeling</p>
# # <p style="text-align: center;">Assignment 4</p>
# ## <p style="text-align: center;">Total points: 75</p>
# ## <p style="text-align: center;">Due: Tuesday, November 12th, submitted via Canvas by 11:59 pm</p>
#
# Your homework should be written in a **Jupyter notebook**. You may work in groups of two if you wish. Your partner needs to be from the same section. Only one student per team needs to submit the assignment on Canvas.  But be sure to include name and UTEID for both students.  Homework groups will be created and managed through Canvas, so please do not arbitrarily change your homework group. If you do change, let the TA know.
#
# Please ensure that the notebook you have uploaded on Canvas is the correct one, you could download the notebook from Canvas to double check that you have submitted the correct version on your notebook.
#
# Also, please make sure your code runs and the graphics (and anything else) are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# ### Name(s)
# 1. Edward Eustachon
# 2. Jeremy Friedman

# %% [markdown]
# ## Question 1 - Expected Risk Minimization (15 pts)
# Consider a binary classification problem with the following loss matrix -
# $$
#    {\begin{array}{ccccc}
#    & & \text{Predicted class} & \text{           } &\\
#    & & C1 & C2 & Reject\\
#    \text{True class} & C1 & 0 & 3 & c  \\
#    & C2 & 2 & 0 & c \\
#   \end{array} }
# $$
# where the cost of rejection is a constant. Determine the prediction that minimizes the expected loss in different ranges of $P(C1|x)$ for the following three cases -
# 1. c = 0
# 2. c = 2
# 3. c = 1

# %% [markdown]
# ### Answer

# %% [markdown]
# 1.

# %% [markdown]
#  Prediction: Reject all entries in the range of P(C1|x).

# %%
x=np.linspace(0, 1, 10000)

plt.figure()
plt.plot(x, 0*x, linestyle='--')
plt.plot(x, 3*x)
plt.plot(x, 2-2*x)
plt.xlabel('Probability')
plt.ylabel('Cost')
plt.show()

# %% [markdown]
# 2.

# %% [markdown]
# Prediction: The curves intersect at p = .04: choose C2 if p < 0.4 and C1 if p > 0.4

# %%
plt.figure()
plt.plot(x, 3*x)
plt.plot(x, 2-2*x)
plt.plot(x, 2*np.ones(10000), linestyle='--')
plt.xlabel('Probability')
plt.ylabel('Cost')
plt.show()

# %% [markdown]
# 3.

# %% [markdown]
# Prediction: Minimum changes at different p-values. Choose C2 if p < 1/3, reject if 1/3 < p < 1/2, choose C1 if p > 1/2

# %%
plt.figure()
plt.plot(x, 3*x)
plt.plot(x, 2-2*x)
plt.plot(x, 1*np.ones(10000), linestyle='--')
plt.xlabel('Probability')
plt.ylabel('Cost')
plt.show()

# %% [markdown]
# ## Question 2 - Concepts (10 pts)

# %% [markdown]
# Emma is a high school student who is creating a model for spam classification, which is well known to be an imbalanced classification problem. During the course of modeling, she had various observations and she is not sure if these observations suggest anything about the correctness of her modeling exercise. You are given two such instances below. For each observation identify what the problem with it may be (if any) and suggest a way to correct it.
#
# 1. She thinks that the most important signal to identify spam emails is the sender. So, she creates a feature called is_sender_spammer and populates it with the percentage of emails sent by the sender that were spam, in the given dataset. The way she created this feature was - for each email, she counted the number of emails sent by each sender which were labeled as true spam and divided by the total number of emails sent by the sender. She then divides the given dataset into train and test and trains a logistic regression classifier using just this one feature. The AUROC on the test dataset comes out to be 0.99. She thinks this is too good to be true. What do you think may be the problem with her approach, and how can this be fixed?
#
# 2. She then changes her approach and tries multiple sets of features with different models. She finds out that whatever features or models she uses the classification accuracy on the test dataset is always above 90%. Why do you think this could happen?

# %% [markdown]
# 1. Number of spam/total number of emails is the true positive rate. Therefore the AUROC score is expected to be high.
#
#
# 2. It's possible that the test dataset's distribution of spam and non-spam emails is not even, resulting in either making up the vast majority of the data. In this case, even a terrible spam filter could easily show a high classification accuracy. For instance, let's assume that 90% of the test dataset consists of non-spam emails. If the model classifies all emails as non-spam, it will show a 90% classification accuracy despite having done no filtering.

# %% [markdown]
# # Question 3 - Churn Prediction (50pts)
#
# In this problem, you are provided with data from a bank. The objective is to process the data and build predictive models to classify if a customer is going to churn or not. You will be using sklearn [pipelines](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) and transformers in this exercise.
#
#
# 1. What proportion of the users in the data churn? (2pts)
# 2. Do credit card users churn more when compared to other users? (use a suitable plot) (3pts)
# 3. Set up the transformer for min-max normalization. Other required transformers are provided. (5pts)
# 4. Scikit-learn provides the capability to create Machine Learning workflows by using a construct known as Pipeline. ML modeling pipelines can be viewed as directed acyclic graphs where each node is an "operator" performing some processing on the data frames or ndarrays. Use this [guide](https://medium.com/vickdata/a-simple-guide-to-scikit-learn-pipelines-4ac0d974bdcf) to understand how to create a pipeline and create a pipeline which has the following steps:<br>
#     a. One hot encoding transformer on the categorical variables.<br>
#     b. Min-max normalization transformer on the continuous variables.<br>
#     c. Logistic Regression model.<br>
#     Using the code for transformers given to you, fit this pipeline on the train set and report the F1 score and AUROC on the test set. (10pts)
# 5. Add the following features to the data:<br>
#     a. Ratio of balance to salary.<br>
#     b. Ratio of tenure to age.<br>
#     c. Ratio of credit score to age.<br>
#    Using this new data, build a similar Logistic Regression pipeline as in the previous question and report the F1 score and AUROC on the test set. We see that the performance of the model improves with these additional features, hence we will be using the new dataset with these additional features from now (this question and all the questions ahead).
#    We have seen that the two classes are imbalanced in the data. We can improve the logistic regression model by changing the importance given to the classes - use the class_weight='balanced' option (by default, both classes have equal importance). Report the F1 score and AUROC on the test set. (10 pts)
# 6. Build multiple MLP pipelines by varying the number of hidden units, activation and optimizer (atleast 12). Plot the ROC curve for the different MLP pipeleines using the test set (in one plot - use markers since the number of colors are limited).  Report your best F1 score on the test set. (10pts)
# 7. Build a decision tree and Gaussian Naive Bayes pipelines. Plot an ROC for these two models, the improved logistic regression model and the best MLP model (in one plot). (5pts).
# 8. The calibration curve gives you a way of testing if your model is well-calibrated or not. Use sklearn's [calibration_curve](https://scikit-learn.org/stable/modules/generated/sklearn.calibration.calibration_curve.html) function to plot the calibration curve for the Gaussian Naive Bayes model, the improved logistic regression model, and the best MLP model and report which models are well-calibrated and which ones are not. (5 pts)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, FeatureUnion
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('q3.csv', delimiter=',')
df.shape
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# #### Answer

# %% [markdown]
# #### (1)

# %%
mask = df['Exited'] == 1
proportion = len(df[mask])/len(df)*100
print('Proportion of churned users: ', proportion)
# Out:
# Proportion of churned users:  20.369999999999997

# %% [markdown]
# #### (2)

# %%
df.groupby('HasCrCard')['Exited'].agg('mean').plot(kind='bar')
prop = df.groupby('HasCrCard')['Exited'].agg('mean')
prop*100
# Out:
# HasCrCard
# 0    20.814941
# 1    20.184266
# Name: Exited, dtype: float64

# %% [markdown]
# Credit card users tend to churn slightly less than those without a card

# %%
#DONOT CHANGE THIS
df_train = df.sample(frac=0.8,random_state=11)
df_test = df.drop(df_train.index)

from sklearn.base import BaseEstimator, TransformerMixin
# We provide the required transformers to build the pipeline.
# Transfomer for performing one hot encoding on a specified categorical column
class OneHotEncoder(BaseEstimator, TransformerMixin):
    
    def __init__(self,col):
        self.col = col
                
    def transform(self, X):
        return pd.get_dummies(X[self.col]) 

    def fit(self, X, y=None):
        return self  
    
# Stateless transformer for selecting a specified columns
class DFSubsetSelector(BaseEstimator,TransformerMixin):
    
    def __init__(self,cols):
        self.cols = cols
        
    def transform(self ,X):
        return X[self.cols]
    
    def fit(self, X, y=None):
        return self
    
class ConcatFeatures(BaseEstimator, TransformerMixin):
    
    def __init__(self,cols,sep="_"):
        self.cols = cols
        self.sep = sep
                
    def transform(self, X):
        concat_col = self.sep.join(self.cols)
        return X.apply(lambda x : self.sep.join([x[col] for col in self.cols]) ,axis=1).to_frame(name = concat_col)

    def fit(self, X, y=None):
        return self

# %% [markdown]
# #### (3)

# %%
class MinMaxTransform(BaseEstimator, TransformerMixin):

    def __init__(self,cols=None):
        self.cols = cols
        
    def transform(self, X):
        return X[self.cols].apply(lambda x: (x-x.min()) / (x.max()-x.min()))
        
    def fit(self, X, y=None):
        return self

# %% [markdown]
# #### (4)

# %%
from sklearn.compose import ColumnTransformer
numeric_features = df_train.select_dtypes(
    include=['int64', 'float64']).drop(['Exited'], axis=1).columns
categorical_features = df_train.select_dtypes(include=['object']).columns

numeric_transformer = Pipeline(steps=[('minmax', MinMaxTransform(numeric_features))])
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(categorical_features))])

preprocessor = ColumnTransformer(
    transformers=[('num', numeric_transformer, numeric_features),
                  ('cat', categorical_transformer, categorical_features)])

# %%
logistic = Pipeline(steps=[('preprocessor', preprocessor), ('classifier', LogisticRegression())])

# %%
y_train = df_train['Exited'].copy()
x_train = df_train.drop('Exited', axis=1)
logistic.fit(x_train, y_train)

x_test = df_test.drop('Exited', axis=1)
y_test = df_test['Exited'].copy()

y_pred = logistic.predict(x_test)
print('AUCROC Score:', roc_auc_score(y_test, y_pred))
print('F1 Score:', f1_score(y_test, y_pred))
# Out:
# AUCROC Score: 0.5908341228901288
# F1 Score: 0.3186813186813187

# %% [markdown]
# #### (5)

# %%
df_train['RatioBalSal'] = df_train['Balance'] / df_train['EstimatedSalary']
df_train['RatioTenAge'] = df_train['Tenure'] / df_train['Age']
df_train['RatioCSAge'] = df_train['CreditScore'] / df_train['Age']

df_test['RatioBalSal'] = df_test['Balance'] / df_test['EstimatedSalary']
df_test['RatioTenAge'] = df_test['Tenure'] / df_test['Age']
df_test['RatioCSAge'] = df_test['CreditScore'] / df_test['Age']

x_train = df_train.drop('Exited', axis=1)
x_test = df_test.drop('Exited', axis=1)

# %%
numeric_features = df_train.select_dtypes(
    include=['int64', 'float64']).drop(['Exited'], axis=1).columns
categorical_features = df_train.select_dtypes(include=['object']).columns

numeric_transformer = Pipeline(steps=[('minmax', MinMaxTransform(numeric_features))])
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(categorical_features))])

preprocessor = ColumnTransformer(
    transformers=[('num', numeric_transformer, numeric_features),
                  ('cat', categorical_transformer, categorical_features)])

implogistic = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', LogisticRegression())])
implogistic.fit(x_train, y_train)

y_hat = implogistic.predict(x_test)
print('AUCROC Score:', roc_auc_score(y_test, y_hat))
print('F1 Score:', f1_score(y_test, y_hat))
# Out:
# AUCROC Score: 0.6097903516922453
# F1 Score: 0.36649214659685864

# %%
implogistic_v2 = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', LogisticRegression(class_weight='balanced'))])
implogistic_v2.fit(x_train, y_train)

y_score = implogistic_v2.predict(x_test)
print('AUCROC Score:', roc_auc_score(y_test, y_score))
print('F1 Score:', f1_score(y_test, y_score))
# Out:
# AUCROC Score: 0.7231783360872465
# F1 Score: 0.514571190674438

# %% [markdown]
# #### (6)

# %%
# %%time

mlp1 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(solver='sgd', random_state=1))])
mlp1.fit(x_train, y_train)
fpr, tpr, threshold = roc_curve(y_test, mlp1.predict_proba(x_test)[:,1])
roc_auc1 = roc_auc_score(y_test, mlp1.predict_proba(x_test)[:,1])

mlp2 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(solver='lbfgs', random_state=1))])
mlp2.fit(x_train, y_train)
fpr2, tpr2, threshold = roc_curve(y_test, mlp2.predict_proba(x_test)[:,1])
roc_auc2 = roc_auc_score(y_test, mlp2.predict_proba(x_test)[:,1])

mlp3 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='logistic', random_state=1))])
mlp3.fit(x_train, y_train)
fpr3, tpr3, threshold = roc_curve(y_test, mlp3.predict_proba(x_test)[:,1])
roc_auc3 = roc_auc_score(y_test, mlp3.predict_proba(x_test)[:,1])

mlp4 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='tanh', random_state=1))])
mlp4.fit(x_train, y_train)
fpr4, tpr4, threshold = roc_curve(y_test, mlp4.predict_proba(x_test)[:,1])
roc_auc4 = roc_auc_score(y_test, mlp4.predict_proba(x_test)[:,1])

mlp5 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='logistic', solver='sgd', random_state=1))])
mlp5.fit(x_train, y_train)
fpr5, tpr5, threshold = roc_curve(y_test, mlp5.predict_proba(x_test)[:,1])
roc_auc5 = roc_auc_score(y_test, mlp5.predict_proba(x_test)[:,1])

mlp6 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='logistic', solver='lbfgs', random_state=1))])
mlp6.fit(x_train, y_train)
fpr6, tpr6, threshold = roc_curve(y_test, mlp6.predict_proba(x_test)[:,1])
roc_auc6 = roc_auc_score(y_test, mlp6.predict_proba(x_test)[:,1])

mlp7 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='tanh', solver='sgd', random_state=1))])
mlp7.fit(x_train, y_train)
fpr7, tpr7, threshold = roc_curve(y_test, mlp7.predict_proba(x_test)[:,1])
roc_auc7 = roc_auc_score(y_test, mlp7.predict_proba(x_test)[:,1])

mlp8 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='tanh', solver='lbfgs', random_state=1))])
mlp8.fit(x_train, y_train)
fpr8, tpr8, threshold = roc_curve(y_test, mlp8.predict_proba(x_test)[:,1])
roc_auc8 = roc_auc_score(y_test, mlp8.predict_proba(x_test)[:,1])

mlp9 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(hidden_layer_sizes=200, solver='lbfgs', random_state=1))])
mlp9.fit(x_train, y_train)
fpr9, tpr9, threshold = roc_curve(y_test, mlp9.predict_proba(x_test)[:,1])
roc_auc9 = roc_auc_score(y_test, mlp9.predict_proba(x_test)[:,1])

mlp10 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(hidden_layer_sizes=200, solver='sgd', random_state=1))])
mlp10.fit(x_train, y_train)
fpr10, tpr10, threshold = roc_curve(y_test, mlp10.predict_proba(x_test)[:,1])
roc_auc10 = roc_auc_score(y_test, mlp10.predict_proba(x_test)[:,1])

mlp11 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(hidden_layer_sizes=200, activation='logistic', solver='sgd', random_state=1))])
mlp11.fit(x_train, y_train)
fpr11, tpr11, threshold = roc_curve(y_test, mlp11.predict_proba(x_test)[:,1])
roc_auc11 = roc_auc_score(y_test, mlp11.predict_proba(x_test)[:,1])

mlp12 = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(hidden_layer_sizes=200, activation='tanh', solver='sgd', random_state=1))])
mlp12.fit(x_train, y_train)
fpr12, tpr12, threshold = roc_curve(y_test, mlp12.predict_proba(x_test)[:,1])
roc_auc12 = roc_auc_score(y_test, mlp12.predict_proba(x_test)[:,1])
# Out:
# Wall time: 1min 10s

# %%
plt.figure(figsize=[8, 10])
plt.title('ROC Curve')
plt.plot(fpr, tpr, label = 'MLP1 AUC = %0.5f' % roc_auc1, color='#000000')
plt.plot(fpr2, tpr2, label = 'MLP2 AUC = %0.5f' % roc_auc2, color='#8A2BE2')
plt.plot(fpr3, tpr3, label = 'MLP3 AUC = %0.5f' % roc_auc3, color='#A52A2A')
plt.plot(fpr4, tpr4, label = 'MLP4 AUC = %0.5f' % roc_auc4, color='#5F9EA0')
plt.plot(fpr5, tpr5, label = 'MLP5 AUC = %0.5f' % roc_auc5, color='#7FFF00')
plt.plot(fpr6, tpr6, label = 'MLP6 AUC = %0.5f' % roc_auc6, color='#0000FF')
plt.plot(fpr7, tpr7, label = 'MLP7 AUC = %0.5f' % roc_auc7, color='#FFFF00')
plt.plot(fpr8, tpr8, label = 'MLP8 AUC = %0.5f' % roc_auc8, color='#EE82EE')
plt.plot(fpr9, tpr9, label = 'MLP9 AUC = %0.5f' % roc_auc9, color='#006400')
plt.plot(fpr10, tpr10, label = 'MLP10 AUC = %0.5f' % roc_auc10, color='#696969')
plt.plot(fpr11, tpr11, label = 'MLP11 AUC = %0.5f' % roc_auc11, color='#BC8F8F')
plt.plot(fpr12, tpr12, label = 'MLP12 AUC = %0.5f' % roc_auc12, color='#8B008B')
plt.legend(loc = 'best')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print('MLP4 F1 Score:', f1_score(y_test, mlp4.predict(x_test)))
# Out:
# MLP4 F1 Score: 0.5834586466165415

# %% [markdown]
# #### (7)

# %%
bayes = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', GaussianNB())])
tree = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', DecisionTreeClassifier())])
Logitprob = implogistic_v2.predict_proba(x_test)
Bayesprob = bayes.fit(x_train, y_train).predict_proba(x_test)
Treeprob = tree.fit(x_train, y_train).predict_proba(x_test)
MLPprob = mlp4.predict_proba(x_test)

fprLogit, tprLogit, threshold = roc_curve(y_test, Logitprob[:,1])
fprNB, tprNB, threshold = roc_curve(y_test, Bayesprob[:,1])
fprTree, tprTree, threshold = roc_curve(y_test, Treeprob[:,1])
fprMLP, tprMLP, threshold = roc_curve(y_test, MLPprob[:,1])

roc_aucLogit = roc_auc_score(y_test, Logitprob[:,1])
roc_aucNB = roc_auc_score(y_test, Bayesprob[:,1])
roc_aucTree = roc_auc_score(y_test, Treeprob[:,1])
roc_aucMLP = roc_auc_score(y_test, MLPprob[:,1])

plt.figure()
plt.title('ROC Curve')
plt.plot(fprLogit, tprLogit, label = 'Logistic AUC = %0.3f' % roc_aucLogit, color='#000000')
plt.plot(fprNB, tprNB, label = 'Gaussian NB AUC = %0.3f' % roc_aucNB, color='#8A2BE2')
plt.plot(fprTree, tprTree, label = 'Tree AUC = %0.3f' % roc_aucTree, color='#A52A2A')
plt.plot(fprMLP, tprMLP, label = 'MLP AUC = %0.3f' % roc_aucMLP, color='#5F9EA0')
plt.legend(loc = 'best')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### (8)

# %%
from sklearn.calibration import calibration_curve

lr = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', LogisticRegression(class_weight='balanced'))])
gnb = Pipeline(steps=[
    ('preprocessor', preprocessor), ('classifier', GaussianNB())])
MLPclass = Pipeline(steps=[
    ('preprocessor', preprocessor), 
    ('classifier', MLPClassifier(activation='tanh', random_state=1))])

plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for clf, name in [(lr, 'Logistic'),
                  (gnb, 'Naive Bayes'),
                  (MLPclass, 'MLP Classifier')]:
    clf.fit(x_train, y_train)
    prob_pos = clf.predict_proba(x_test)[:, 1]
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_test, prob_pos, n_bins=10)
    ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (name, ))
    ax2.hist(prob_pos, range=(0, 1), bins=10, label=name,
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="lower right")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.show()
